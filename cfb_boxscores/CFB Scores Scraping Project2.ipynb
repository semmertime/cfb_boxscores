# %%
import requests
import pandas as pd
from datetime import timedelta
pd.set_option('display.max_columns', 100) 
API_KEY = "qs6/qOme90jX/egZWGD1kNe2KIZnhHulZAFcBnvvQH1F65nDEVOSxAEvv/LsSy09"

# %%
def get_fbs_scores(season):
    url = "https://api.collegefootballdata.com/games"
    params = {
        "year": season,
        "seasonType": "both",
        "division": "fbs"
    }
    headers = {
        "Authorization": f"Bearer {API_KEY}"
    }

    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()
    games = response.json()

    df = pd.DataFrame(games)
    # Only the selected columns
    cols = [
        "id",
        "week",
        "seasonType",
        "startDate",
        "completed",
        "venue",
        "neutralSite",
        "conferenceGame",
        "homeTeam",
        "homeClassification",
        "homeConference",
        "homePoints",
        "homeLineScores",
        "awayTeam",
        "awayClassification",
        "awayConference",
        "awayPoints",
        "awayLineScores",
        "excitementIndex"
    ]
    df_out = df[cols]
    return df_out

# Example usage: 2024, Week 1
df_scores = get_fbs_scores(2024)
df_scores  # In Jupyter, this will show the nicely formatted table!
# Out:
#              id  week  seasonType                 startDate  completed  \
# 0     401693677     1     regular  2024-08-24T04:00:00.000Z       True
# 1     401635525     1     regular  2024-08-24T16:00:00.000Z       True
# 2     401654665     1     regular  2024-08-24T19:30:00.000Z       True
# 3     401643697     1     regular  2024-08-24T20:00:00.000Z       True
# 4     401654662     1     regular  2024-08-24T23:00:00.000Z       True
# ...         ...   ...         ...                       ...        ...
# 3796  401741208     1  postseason  2025-01-06T01:00:00.000Z       True
# 3797  401680057     1  postseason  2025-01-07T00:00:00.000Z       True
# 3798  401677189     1  postseason  2025-01-10T00:30:00.000Z       True
# 3799  401677191     1  postseason  2025-01-11T00:30:00.000Z       True
# 3800  401677192     1  postseason  2025-01-21T00:30:00.000Z       True
#
#                                     venue  neutralSite  conferenceGame  \
# 0                                    None         True           False
# 1                           Aviva Stadium         True            True
# 2     Memorial Stadium (Stephenville, TX)        False           False
# 3                 University Stadium (NM)        False           False
# 4                            Cramton Bowl         True           False
# ...                                   ...          ...             ...
# 3796                 BBVA Compass Stadium         True           False
# 3797                       Toyota Stadium         True           False
# 3798                    Hard Rock Stadium         True           False
# 3799                         AT&T Stadium         True           False
# 3800                Mercedes-Benz Stadium         True           False
#
#                       homeTeam homeClassification    homeConference  \
# 0                 Lincoln (CA)                 ii   Independent DII
# 1                 Georgia Tech                fbs               ACC
# 2               Tarleton State                fcs               UAC
# 3                   New Mexico                fbs     Mountain West
# 4     Southeast Missouri State                fcs     Big South-OVC
# ...                        ...                ...               ...
# 3796     North Central College                iii              CCIW
# 3797             Montana State                fcs           Big Sky
# 3798                Penn State                fbs           Big Ten
# 3799                     Texas                fbs               SEC
# 3800                Notre Dame                fbs  FBS Independents
#
#       homePoints  homeLineScores                   awayTeam  \
# 0            7.0    [0, 0, 0, 7]           College of Idaho
# 1           24.0   [7, 7, 0, 10]              Florida State
# 2           26.0  [16, 10, 0, 0]                    McNeese
# 3           31.0  [10, 14, 7, 0]              Montana State
# 4           37.0   [7, 6, 8, 16]              North Alabama
# ...          ...             ...                        ...
# 3796        41.0   [7, 7, 7, 20]  University of Mount Union
# 3797        32.0  [0, 3, 15, 14]         North Dakota State
# 3798        24.0  [0, 10, 0, 14]                 Notre Dame
# 3799        14.0    [0, 7, 7, 0]                 Ohio State
# 3800        23.0    [7, 0, 8, 8]                 Ohio State
#
#      awayClassification    awayConference  awayPoints   awayLineScores  \
# 0                  None              None        45.0  [14, 7, 14, 10]
# 1                   fbs               ACC        21.0     [8, 6, 0, 7]
# 2                   fcs         Southland        23.0    [7, 0, 3, 13]
# 3                   fcs           Big Sky        35.0   [0, 14, 0, 21]
# 4                   fcs               UAC        15.0     [8, 7, 0, 0]
# ...                 ...               ...         ...              ...
# 3796                iii              Ohio        25.0     [7, 3, 7, 8]
# 3797                fcs              MVFC        35.0   [14, 7, 0, 14]
# 3798                fbs  FBS Independents        27.0    [0, 3, 7, 17]
# 3799                fbs           Big Ten        28.0    [7, 7, 0, 14]
# 3800                fbs           Big Ten        34.0   [0, 21, 10, 3]
#
#       excitementIndex
# 0                 NaN
# 1            7.822224
# 2            5.564025
# 3            4.927318
# 4            7.171901
# ...               ...
# 3796              NaN
# 3797         4.820656
# 3798         8.450324
# 3799         6.155203
# 3800         2.819260
#
# [3801 rows x 19 columns]

# %%
def clean_scores_df(df):
    df = df.copy()
    
    # Rename columns (including Venue)
    df = df.rename(columns={
        'id': 'Game_ID',
        'week': 'Week',
        'seasonType': 'Season_Type',
        'startDate': 'Start_Date',
        'venue': 'Venue',
        'completed': 'Completed',
        'neutralSite': 'Neutral_Site',
        'conferenceGame': 'Conference_Game',
        'homeTeam': 'Home_Team',
        'homeClassification': 'Home_Classification',
        'homeConference': 'Home_Conference',
        'homePoints': 'Home_Pts',
        'homeLineScores': 'Home_Line_Scores',
        'awayTeam': 'Away_Team',
        'awayClassification': 'Away_Classification',
        'awayConference': 'Away_Conference',
        'awayPoints': 'Away_Pts',
        'awayLineScores': 'Away_Line_Scores',
        'excitementIndex': 'Excitement'
    })
    
    # Capitalize all values in Season_Type
    df['Season_Type'] = df['Season_Type'].str.title()
    
    # Convert Start_Date to datetime (UTC)
    df['Start_DateTime'] = pd.to_datetime(df['Start_Date'], utc=True)
    df['Start_DateTime_EST'] = df['Start_DateTime'].dt.tz_convert('US/Eastern')

    # Create separate Start_Date and Start_Time columns in Eastern
    # Format date as "Fri, Aug. 29, 2024"
    df['Start_Date'] = df['Start_DateTime_EST'].dt.strftime('%a, %b. %d, %Y')
    df['Start_Time'] = df['Start_DateTime_EST'].dt.strftime('%H:%M')

    # Completed and Neutral_Site to Yes/No
    for col in ['Completed', 'Neutral_Site']:
        df[col] = df[col].apply(lambda x: 'Yes' if x else 'No')
    
    # Conference_Game: Non-Conf if False, else use conference name (from home or away)
    def get_conf(row):
        if not row['Conference_Game']:
            return 'Non-Conf'
        return row['Home_Conference'] if row['Home_Conference'] else row['Away_Conference']
    df['Conference_Game'] = df.apply(get_conf, axis=1)
    
    # Home/Away_Classification fully uppercase
    df['Home_Classification'] = df['Home_Classification'].str.upper()
    df['Away_Classification'] = df['Away_Classification'].str.upper()
    
    # Filter: at least one FBS team
    df = df[(df['Home_Classification'] == 'FBS') | (df['Away_Classification'] == 'FBS')]
    
    # Points as integer (remove decimals)
    df['Home_Pts'] = pd.to_numeric(df['Home_Pts'], errors='coerce').fillna(0).astype(int)
    df['Away_Pts'] = pd.to_numeric(df['Away_Pts'], errors='coerce').fillna(0).astype(int)
    
    # Excitement_Index: one decimal
    df['Excitement'] = pd.to_numeric(df['Excitement'], errors='coerce').round(1)
    
    # Keep only last 6 digits of Game_ID
    df['Game_ID'] = df['Game_ID'].astype(str).str[-6:]
    
    # Break out line scores (handle missing or short lists gracefully)
    def get_q(scores, idx):
        try:
            return int(scores[idx])
        except Exception:
            return 0

    # Home line scores
    df['Home_1Q'] = df['Home_Line_Scores'].apply(lambda x: get_q(x, 0) if isinstance(x, list) else 0)
    df['Home_2Q'] = df['Home_Line_Scores'].apply(lambda x: get_q(x, 1) if isinstance(x, list) else 0)
    df['Home_3Q'] = df['Home_Line_Scores'].apply(lambda x: get_q(x, 2) if isinstance(x, list) else 0)
    df['Home_4Q'] = df['Home_Line_Scores'].apply(lambda x: get_q(x, 3) if isinstance(x, list) else 0)

    # Away line scores
    df['Away_1Q'] = df['Away_Line_Scores'].apply(lambda x: get_q(x, 0) if isinstance(x, list) else 0)
    df['Away_2Q'] = df['Away_Line_Scores'].apply(lambda x: get_q(x, 1) if isinstance(x, list) else 0)
    df['Away_3Q'] = df['Away_Line_Scores'].apply(lambda x: get_q(x, 2) if isinstance(x, list) else 0)
    df['Away_4Q'] = df['Away_Line_Scores'].apply(lambda x: get_q(x, 3) if isinstance(x, list) else 0)

    mask = df['Season_Type'] == 'Regular'
    df_reg = df[mask].sort_values('Start_DateTime_EST')
    week = 0
    week_cuts = []

    # Find the first week start (first game's date, but with time set to 00:00:00, next Tuesday)
    first_date = df_reg.iloc[0]['Start_DateTime_EST']
    # Move to Tuesday midnight of that week
    first_tuesday = first_date + timedelta(days=(1 - first_date.weekday()) % 7)
    first_tuesday = first_tuesday.replace(hour=0, minute=0, second=0, microsecond=0)
    if first_date > first_tuesday:
        current_week_cut = first_tuesday
    else:
        # If first game is before Tuesday, that's week 0
        current_week_cut = first_tuesday

    week_list = []
    for dt in df_reg['Start_DateTime_EST']:
        if dt >= current_week_cut:
            week += 1
            current_week_cut += timedelta(days=7)
        week_list.append(week)
    df.loc[mask, 'Week'] = week_list

    # For all non-regular season, set week as 'Post-Season'
    df['Week'] = df['Week'].astype(str)
    df.loc[df['Season_Type'] != 'Regular', 'Week'] = 'Post-Season'
    df['Week'] = df['Week'].astype(str)

    # Reorder columns (optional)
    final_cols = [
        'Week', 'Start_Date', 'Start_Time', 'Venue',
        'Completed', 'Neutral_Site', 'Conference_Game', 'Home_Team', 'Home_Pts',
        'Home_1Q', 'Home_2Q', 'Home_3Q', 'Home_4Q', 'Away_Team', 'Away_Pts',
        'Away_1Q', 'Away_2Q', 'Away_3Q', 'Away_4Q', 'Excitement'
    ]
    df = df[final_cols]

    return df

# %%
df_clean = clean_scores_df(df_scores)
df_clean.head()
# Out:
#    Week          Start_Date Start_Time                                  Venue  \
# 1     0  Sat, Aug. 24, 2024      12:00                          Aviva Stadium
# 3     0  Sat, Aug. 24, 2024      16:00                University Stadium (NM)
# 6     0  Sat, Aug. 24, 2024      20:00                         Mackay Stadium
# 7     0  Sat, Aug. 24, 2024      23:59  Clarence T.C. Ching Athletics Complex
# 11    1  Thu, Aug. 29, 2024      18:00                            SHI Stadium
#
#    Completed Neutral_Site Conference_Game     Home_Team  Home_Pts  Home_1Q  \
# 1        Yes          Yes             ACC  Georgia Tech        24        7
# 3        Yes           No        Non-Conf    New Mexico        31       10
# 6        Yes           No        Non-Conf        Nevada        24        7
# 7        Yes           No        Non-Conf       Hawai'i        35       14
# 11       Yes           No        Non-Conf       Rutgers        44        7
#
#     Home_2Q  Home_3Q  Home_4Q       Away_Team  Away_Pts  Away_1Q  Away_2Q  \
# 1         7        0       10   Florida State        21        8        6
# 3        14        7        0   Montana State        35        0       14
# 6        10        7        0             SMU        29        0       10
# 7         0        7       14  Delaware State        14        0        7
# 11       10       14       13          Howard         7        0        7
#
#     Away_3Q  Away_4Q  Excitement
# 1         0        7         7.8
# 3         0       21         4.9
# 6         3       16         7.7
# 7         7        0         5.2
# 11        0        0         4.7

# %%
df_scores_2025 = get_fbs_scores(2025)
df_scores_2025
# Out:
#              id  week seasonType                 startDate  completed  \
# 0     401767126     1    regular  2025-08-23T04:00:00.000Z      False
# 1     401767476     1    regular  2025-08-23T04:00:00.000Z      False
# 2     401756846     1    regular  2025-08-23T16:00:00.000Z      False
# 3     401756847     1    regular  2025-08-23T22:30:00.000Z      False
# 4     401767135     1    regular  2025-08-23T23:00:00.000Z      False
# ...         ...   ...        ...                       ...        ...
# 1593  401752921    14    regular  2025-11-29T17:00:00.000Z      False
# 1594  401757313    14    regular  2025-11-29T20:30:00.000Z      False
# 1595  401752946    14    regular  2025-11-29T23:30:00.000Z      False
# 1596  401760425    14    regular  2025-11-30T02:00:00.000Z      False
# 1597  401762521    16    regular  2025-12-13T20:00:00.000Z      False
#
#                                         venue  neutralSite  conferenceGame  \
# 0                           Hillsboro Stadium        False           False
# 1     Manning Field at John L. Guidry Stadium        False            True
# 2                               Aviva Stadium         True            True
# 3                            Memorial Stadium        False           False
# 4                                Cramton Bowl         True           False
# ...                                       ...          ...             ...
# 1593                         Michigan Stadium        False            True
# 1594                    Williams Stadium (VA)        False            True
# 1595                               Gesa Field        False            True
# 1596                           Mackay Stadium        False            True
# 1597                         M&T Bank Stadium         True            True
#
#               homeTeam homeClassification     homeConference homePoints  \
# 0       Portland State                fcs            Big Sky       None
# 1             Nicholls                fcs          Southland       None
# 2           Iowa State                fbs             Big 12       None
# 3               Kansas                fbs             Big 12       None
# 4               Mercer                fcs           Southern       None
# ...                ...                ...                ...        ...
# 1593          Michigan                fbs            Big Ten       None
# 1594           Liberty                fbs     Conference USA       None
# 1595  Washington State                fbs             Pac-12       None
# 1596            Nevada                fbs      Mountain West       None
# 1597              Navy                fbs  American Athletic       None
#
#      homeLineScores        awayTeam awayClassification     awayConference  \
# 0              None  Tarleton State                fcs                UAC
# 1              None  Incarnate Word                fcs          Southland
# 2              None    Kansas State                fbs             Big 12
# 3              None    Fresno State                fbs      Mountain West
# 4              None        UC Davis                fcs            Big Sky
# ...             ...             ...                ...                ...
# 1593           None      Ohio State                fbs            Big Ten
# 1594           None  Kennesaw State                fbs     Conference USA
# 1595           None    Oregon State                fbs             Pac-12
# 1596           None            UNLV                fbs      Mountain West
# 1597           None            Army                fbs  American Athletic
#
#      awayPoints awayLineScores excitementIndex
# 0          None           None            None
# 1          None           None            None
# 2          None           None            None
# 3          None           None            None
# 4          None           None            None
# ...         ...            ...             ...
# 1593       None           None            None
# 1594       None           None            None
# 1595       None           None            None
# 1596       None           None            None
# 1597       None           None            None
#
# [1598 rows x 19 columns]

# %%
df_clean_2025 = clean_scores_df(df_scores_2025)
df_clean_2025.head()
# Out:
#    Week          Start_Date Start_Time  \
# 2     0  Sat, Aug. 23, 2025      12:00
# 3     0  Sat, Aug. 23, 2025      18:30
# 5     0  Sat, Aug. 23, 2025      19:00
# 6     0  Sat, Aug. 23, 2025      19:30
# 11    1  Thu, Aug. 28, 2025      00:00
#
#                                      Venue Completed Neutral_Site  \
# 2                            Aviva Stadium        No          Yes
# 3                         Memorial Stadium        No           No
# 5   Houchens Industries-L.T. Smith Stadium        No           No
# 6    Clarence T.C. Ching Athletics Complex        No           No
# 11                      Snapdragon Stadium        No           No
#
#    Conference_Game         Home_Team  Home_Pts  Home_1Q  Home_2Q  Home_3Q  \
# 2           Big 12        Iowa State         0        0        0        0
# 3         Non-Conf            Kansas         0        0        0        0
# 5   Conference USA  Western Kentucky         0        0        0        0
# 6         Non-Conf           Hawai'i         0        0        0        0
# 11        Non-Conf   San Diego State         0        0        0        0
#
#     Home_4Q     Away_Team  Away_Pts  Away_1Q  Away_2Q  Away_3Q  Away_4Q  \
# 2         0  Kansas State         0        0        0        0        0
# 3         0  Fresno State         0        0        0        0        0
# 5         0   Sam Houston         0        0        0        0        0
# 6         0      Stanford         0        0        0        0        0
# 11        0   Stony Brook         0        0        0        0        0
#
#     Excitement
# 2          NaN
# 3          NaN
# 5          NaN
# 6          NaN
# 11         NaN

# %%
def make_game_card(row):
    # Determine winner/loser and their score colors (only for outside scores)
    if row['Home_Pts'] > row['Away_Pts']:
        home_score_color = "#155724"  # dark green
        away_score_color = "#A93226"  # dark red
    elif row['Home_Pts'] < row['Away_Pts']:
        home_score_color = "#A93226"
        away_score_color = "#155724"
    else:
        home_score_color = away_score_color = "#555"  # Tie (gray)
    
    card = f"""
    <div style="border:1px solid #ddd; border-radius:10px; padding:16px; margin-bottom:20px; background:#FFFBF2; max-width:640px;">
        <div style="display:flex; justify-content:space-between; align-items:center; font-family:sans-serif;">
            <div style="text-align:center; flex:1;">
                <span style="font-weight:bold; font-size:22px;">{row['Away_Team']}</span><br>
                <span style="font-size:32px; color:{away_score_color}; font-weight:bold;">{row['Away_Pts']}</span>
            </div>
            <div style="text-align:center; flex:2;">
                <table style="margin:auto; font-size:14px; border-collapse:separate; border-spacing:0; border: 1px solid #000; border-radius:8px; overflow:hidden;">
                  <tr style='background-color:#eaf6ff;'>
                    <th style="font-weight:bold; padding:4px 8px;"></th>
                    <th style="font-weight:bold; padding:4px 8px;">1Q</th>
                    <th style="font-weight:bold; padding:4px 8px;">2Q</th>
                    <th style="font-weight:bold; padding:4px 8px;">3Q</th>
                    <th style="font-weight:bold; padding:4px 8px;">4Q</th>
                    <th style="font-weight:bold; padding:4px 8px;">T</th>
                  </tr>
                  <tr style="background-color:#fff;">
                    <td style='text-align:right; padding:4px 8px;'>{row['Away_Team']}</td>
                    <td style='text-align:center; color:#000;'>{row['Away_1Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Away_2Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Away_3Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Away_4Q']}</td>
                    <td style='font-weight:bold; text-align:center; color:#000;'>{row['Away_Pts']}</td>
                  </tr>
                  <tr style="background-color:#eaf6ff;">
                    <td style='text-align:right; padding:4px 8px;'>{row['Home_Team']}</td>
                    <td style='text-align:center; color:#000;'>{row['Home_1Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Home_2Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Home_3Q']}</td>
                    <td style='text-align:center; color:#000;'>{row['Home_4Q']}</td>
                    <td style='font-weight:bold; text-align:center; color:#000;'>{row['Home_Pts']}</td>
                  </tr>
                </table>
                <div style="margin-top:10px; color:#333; font-size:13px;">
                    {row['Start_Date']} &bull; {row['Start_Time']} ET<br>
                    Venue: <b>{row['Venue']}</b><br>
                    Conference: <b>{row['Conference_Game']}</b> &nbsp;|&nbsp; Excitement: <b>{row['Excitement']}</b>
                </div>
            </div>
            <div style="text-align:center; flex:1;">
                <span style="font-weight:bold; font-size:22px;">{row['Home_Team']}</span><br>
                <span style="font-size:32px; color:{home_score_color}; font-weight:bold;">{row['Home_Pts']}</span>
            </div>
        </div>
    </div>
    """
    return card

# %%
# Filter for completed games on Aug 24, 2024
df_games = df_clean[
    (df_clean['Completed'] == 'Yes') &
    (df_clean['Start_Date'] == 'Sat, Aug. 24, 2024')
]

# %%
report_html = ""
for _, row in df_games.iterrows():
    report_html += make_game_card(row)
from IPython.display import display, HTML
display(HTML(report_html))
# Out:
#     <div style="border:1px solid #ddd; border-radius:10px; padding:16px; margin-bottom:20px; background:#FFFBF2; max-width:640px;">
#         <div style="display:flex; justify-content:space-between; align-items:center; font-family:sans-serif;">
#             <div style="text-align:center; flex:1;">
#                 <span style="font-weight:bold; font-size:22px;">Florida State</span><br>
#                 <span style="font-size:32px; color:#A93226; font-weight:bold;">21</span>
#             </div>
#             <div style="text-align:center; flex:2;">
#                 <table style="margin:auto; font-size:14px; border-collapse:separate; border-spacing:0; border: 1px solid #000; border-radius:8px; overflow:hidden;">
#                   <tr style='background-color:#eaf6ff;'>
#                     <th style="font-weight:bold; padding:4px 8px;"></th>
#                     <th style="font-weight:bold; padding:4px 8px;">1Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">2Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">3Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">4Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">T</th>
#                   </tr>
#                   <tr style="background-color:#fff;">
#                     <td style='text-align:right; padding:4px 8px;'>Florida State</td>
#                     <td style='text-align:center; color:#000;'>8</td>
#                     <td style='text-align:center; color:#000;'>6</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='font-weight:bold; text-align:center; color:#000;'>21</td>
#                   </tr>
#                   <tr style="background-color:#eaf6ff;">
#                     <td style='text-align:right; padding:4px 8px;'>Georgia Tech</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='text-align:center; color:#000;'>10</td>
#                     <td style='font-weight:bold; text-align:center; color:#000;'>24</td>
#                   </tr>
#                 </table>
#                 <div style="margin-top:10px; color:#333; font-size:13px;">
#                     Sat, Aug. 24, 2024 &bull; 12:00 ET<br>
#                     Venue: <b>Aviva Stadium</b><br>
#                     Conference: <b>ACC</b> &nbsp;|&nbsp; Excitement: <b>7.8</b>
#                 </div>
#             </div>
#             <div style="text-align:center; flex:1;">
#                 <span style="font-weight:bold; font-size:22px;">Georgia Tech</span><br>
#                 <span style="font-size:32px; color:#155724; font-weight:bold;">24</span>
#             </div>
#         </div>
#     </div>
#
#     <div style="border:1px solid #ddd; border-radius:10px; padding:16px; margin-bottom:20px; background:#FFFBF2; max-width:640px;">
#         <div style="display:flex; justify-content:space-between; align-items:center; font-family:sans-serif;">
#             <div style="text-align:center; flex:1;">
#                 <span style="font-weight:bold; font-size:22px;">Montana State</span><br>
#                 <span style="font-size:32px; color:#155724; font-weight:bold;">35</span>
#             </div>
#             <div style="text-align:center; flex:2;">
#                 <table style="margin:auto; font-size:14px; border-collapse:separate; border-spacing:0; border: 1px solid #000; border-radius:8px; overflow:hidden;">
#                   <tr style='background-color:#eaf6ff;'>
#                     <th style="font-weight:bold; padding:4px 8px;"></th>
#                     <th style="font-weight:bold; padding:4px 8px;">1Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">2Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">3Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">4Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">T</th>
#                   </tr>
#                   <tr style="background-color:#fff;">
#                     <td style='text-align:right; padding:4px 8px;'>Montana State</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='text-align:center; color:#000;'>14</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='text-align:center; color:#000;'>21</td>
#                     <td style='font-weight:bold; text-align:center; color:#000;'>35</td>
#                   </tr>
#                   <tr style="background-color:#eaf6ff;">
#                     <td style='text-align:right; padding:4px 8px;'>New Mexico</td>
#                     <td style='text-align:center; color:#000;'>10</td>
#                     <td style='text-align:center; color:#000;'>14</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='font-weight:bold; text-align:center; color:#000;'>31</td>
#                   </tr>
#                 </table>
#                 <div style="margin-top:10px; color:#333; font-size:13px;">
#                     Sat, Aug. 24, 2024 &bull; 16:00 ET<br>
#                     Venue: <b>University Stadium (NM)</b><br>
#                     Conference: <b>Non-Conf</b> &nbsp;|&nbsp; Excitement: <b>4.9</b>
#                 </div>
#             </div>
#             <div style="text-align:center; flex:1;">
#                 <span style="font-weight:bold; font-size:22px;">New Mexico</span><br>
#                 <span style="font-size:32px; color:#A93226; font-weight:bold;">31</span>
#             </div>
#         </div>
#     </div>
#
#     <div style="border:1px solid #ddd; border-radius:10px; padding:16px; margin-bottom:20px; background:#FFFBF2; max-width:640px;">
#         <div style="display:flex; justify-content:space-between; align-items:center; font-family:sans-serif;">
#             <div style="text-align:center; flex:1;">
#                 <span style="font-weight:bold; font-size:22px;">SMU</span><br>
#                 <span style="font-size:32px; color:#155724; font-weight:bold;">29</span>
#             </div>
#             <div style="text-align:center; flex:2;">
#                 <table style="margin:auto; font-size:14px; border-collapse:separate; border-spacing:0; border: 1px solid #000; border-radius:8px; overflow:hidden;">
#                   <tr style='background-color:#eaf6ff;'>
#                     <th style="font-weight:bold; padding:4px 8px;"></th>
#                     <th style="font-weight:bold; padding:4px 8px;">1Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">2Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">3Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">4Q</th>
#                     <th style="font-weight:bold; padding:4px 8px;">T</th>
#                   </tr>
#                   <tr style="background-color:#fff;">
#                     <td style='text-align:right; padding:4px 8px;'>SMU</td>
#                     <td style='text-align:center; color:#000;'>0</td>
#                     <td style='text-align:center; color:#000;'>10</td>
#                     <td style='text-align:center; color:#000;'>3</td>
#                     <td style='text-align:center; color:#000;'>16</td>
#                     <td style='font-weight:bold; text-align:center; color:#000;'>29</td>
#                   </tr>
#                   <tr style="background-color:#eaf6ff;">
#                     <td style='text-align:right; padding:4px 8px;'>Nevada</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='text-align:center; color:#000;'>10</td>
#                     <td style='text-align:center; color:#000;'>7</td>
#                     <td style='text-align:

# %%
df_clean['Home_Team'].unique()
# Out:
# array(['Georgia Tech', 'New Mexico', 'Nevada', "Hawai'i", 'Rutgers',
#        'Wake Forest', 'UCF', 'NC State', 'UL Monroe', 'Buffalo',
#        'Bowling Green', 'Central Michigan', 'Arkansas', 'Toledo',
#        'Missouri', 'Minnesota', 'UAB', 'Tulane', 'Tulsa', 'Kansas',
#        'Colorado', 'Jacksonville State', 'Utah', 'Illinois',
#        'San José State', 'Army', 'Oklahoma', 'Michigan State', 'Duke',
#        'Wisconsin', 'Stanford', 'Utah State', 'Iowa', 'Purdue', 'Navy',
#        'Louisville', 'Vanderbilt', 'West Virginia', 'Maryland',
#        'Pittsburgh', 'Georgia', 'Tennessee', 'Oklahoma State',
#        'Cincinnati', 'Washington State', 'Nebraska', 'Iowa State',
#        'App State', 'Northern Illinois', 'Air Force', 'Massachusetts',
#        'Indiana', 'Ohio State', 'Florida', 'Syracuse', 'Northwestern',
#        'UTSA', 'Texas', 'Georgia Southern', 'South Carolina',
#        'California', 'Marshall', 'South Alabama', 'East Carolina',
#        'Mississippi State', 'Liberty', 'Virginia', 'Oregon State',
#        'Middle Tennessee', 'Ole Miss', 'Kansas State', 'Arkansas State',
#        'South Florida', 'Rice', 'Houston', 'Alabama', 'Baylor', 'Memphis',
#        'Troy', 'Texas Tech', 'Texas A&M', 'Auburn', 'Oregon', 'Michigan',
#        'Kentucky', 'Texas State', 'Louisiana', 'SMU', 'Louisiana Tech',
#        'San Diego State', 'Charlotte', 'BYU', 'New Mexico State',
#        'Arizona State', 'Arizona', 'Washington', 'LSU', 'Florida State',
#        'UConn', 'Penn State', 'Florida Atlantic', 'Ball State',
#        'Kent State', 'UNLV', 'Notre Dame', 'Boston College',
#        'North Carolina', 'Wyoming', 'Virginia Tech', 'Miami',
#        'Florida International', 'Old Dominion', 'Ohio', 'James Madison',
#        'Georgia State', 'Western Kentucky', 'Coastal Carolina',
#        'Kennesaw State', 'Southern Miss', 'Colorado State', 'North Texas',
#        'Clemson', 'TCU', 'UTEP', 'Fresno State', 'USC', 'Miami (OH)',
#        'Temple', 'Akron', 'Western Michigan', 'Sam Houston',
#        'Eastern Michigan', 'UCLA', 'Boise State'], dtype=object)

# %%
import os

logo_dir = 'FBS-Logo-Library-main/CFB Logos'
all_logo_files = [f for f in os.listdir(logo_dir) if f.endswith('.png')]

# Try to match based on team names
auto_team_to_logo = {}
for team in df_clean['Home_Team'].unique():
    # Replace spaces/hyphens with underscores, remove special chars
    possible_files = [f for f in all_logo_files if team.replace(" ", "_").replace("-", "_") in f]
    if possible_files:
        auto_team_to_logo[team] = possible_files[0]
    else:
        print(f"No match for {team}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[86], line 4
#       1 import os
#       3 logo_dir = 'FBS-Logo-Library-main/CFB Logos'
# ----> 4 all_logo_files = [f for f in os.listdir(logo_dir) if f.endswith('.png')]
#       6 # Try to match based on team names
#       7 auto_team_to_logo = {}
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'FBS-Logo-Library-main/CFB Logos'
